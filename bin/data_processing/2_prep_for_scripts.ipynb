# %% [markdown]
# # Prep for CellRanger ARC
# Use this notebook to prepare the donwloaded data for processing with CellRanger ARC. This should also be usable with Chromap and Kallisto.

# %%
# Imports
import os
import glob
import pickle
import pandas as pd

# %%
# Set paths
sra_metadata = "/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/metadata/07Nov23/SRP366403_metadata.tsv"
seqkit_stats = "/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/metadata/09Nov23/fastq_stats.tsv"
fastq_dir = "/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/"
metadata_dir = "/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/metadata/09Nov23"

# %%
# Grab fastq dirs
datasets = glob.glob(os.path.join(fastq_dir, "*"))
datasets = [x for x in datasets if "vdb_validate_all.out" not in x]
len(datasets), datasets[:5]
# Out:
# (36,
#  ['/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642887',
#   '/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642891',
#   '/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642896',
#   '/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642878',
#   '/cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520828'])

# %% [markdown]
# # Load data

# %%
# Load SRA metadata
sra_df = pd.read_csv(sra_metadata, sep="\t")
sra_df["sample_id"] = sra_df["experiment_title"].str.split(":").str[1].str.split("[").str[0].str.strip()
sra_df["sample_id"] = sra_df["sample_id"].str.replace(" ", "_")
sra_df["multiome_part"] = sra_df["experiment_title"].str.split(";").str[-1].str.strip()
sra_df = sra_df.drop_duplicates(["experiment_accession", "sample_id", "multiome_part"]).reset_index(drop=True)
sra_df.head()
# Out:
#   run_accession study_accession  \
# 0   SRR18511696       SRP366403
# 1   SRR18511697       SRP366403
# 2   SRR18511698       SRP366403
# 3   SRR18511699       SRP366403
# 4   SRR18511704       SRP366403
#
#                                          study_title experiment_accession  \
# 0  Single nuclei multiomics of human stem cell-de...          SRX14642877
# 1  Single nuclei multiomics of human stem cell-de...          SRX14642878
# 2  Single nuclei multiomics of human stem cell-de...          SRX14642879
# 3  Single nuclei multiomics of human stem cell-de...          SRX14642880
# 4  Single nuclei multiomics of human stem cell-de...          SRX14642885
#
#                                     experiment_title  \
# 0  GSM5979664: SC-Islet 1 [ATAC-Seq]; Homo sapien...
# 1  GSM5979665: SC-Islet 1 [RNA-Seq]; Homo sapiens...
# 2  GSM5979666: SC-Islet 2 [ATAC-Seq]; Homo sapien...
# 3  GSM5979667: SC-Islet 2 [RNA-Seq]; Homo sapiens...
# 4  GSM5979672: SC-Islet Stage6 week 2 [ATAC-Seq];...
#
#                                      experiment_desc  organism_taxid  \
# 0  GSM5979664: SC-Islet 1 [ATAC-Seq]; Homo sapien...            9606
# 1  GSM5979665: SC-Islet 1 [RNA-Seq]; Homo sapiens...            9606
# 2  GSM5979666: SC-Islet 2 [ATAC-Seq]; Homo sapien...            9606
# 3  GSM5979667: SC-Islet 2 [RNA-Seq]; Homo sapiens...            9606
# 4  GSM5979672: SC-Islet Stage6 week 2 [ATAC-Seq];...            9606
#
#   organism_name  library_name library_strategy  ...     stage  \
# 0  Homo sapiens           NaN         ATAC-seq  ...  In vitro
# 1  Homo sapiens           NaN          RNA-Seq  ...  In vitro
# 2  Homo sapiens           NaN         ATAC-seq  ...  In vitro
# 3  Homo sapiens           NaN          RNA-Seq  ...  In vitro
# 4  Homo sapiens           NaN         ATAC-seq  ...  In vitro
#
#                                             kit used ena_fastq_http  \
# 0  10x Single Cell Multiome ATAC + Gene Expressio...            NaN
# 1  10x Single Cell Multiome ATAC + Gene Expressio...            NaN
# 2  10x Single Cell Multiome ATAC + Gene Expressio...            NaN
# 3  10x Single Cell Multiome ATAC + Gene Expressio...            NaN
# 4  10x Single Cell Multiome ATAC + Gene Expressio...            NaN
#
#                                     ena_fastq_http_1  \
# 0  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/096...
# 1  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/097...
# 2  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/098...
# 3  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/099...
# 4  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/004...
#
#                                     ena_fastq_http_2 ena_fastq_ftp  \
# 0  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/096...           NaN
# 1  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/097...           NaN
# 2  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/098...           NaN
# 3  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/099...           NaN
# 4  http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR185/004...           NaN
#
#                                      ena_fastq_ftp_1  \
# 0  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...
# 1  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...
# 2  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...
# 3  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...
# 4  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...
#
#                                      ena_fastq_ftp_2               sample_id  \
# 0  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...              SC-Islet_1
# 1  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...              SC-Islet_1
# 2  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...              SC-Islet_2
# 3  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...              SC-Islet_2
# 4  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR185/...  SC-Islet_Stage6_week_2
#
#    multiome_part
# 0       ATAC-seq
# 1        RNA-Seq
# 2       ATAC-seq
# 3        RNA-Seq
# 4       ATAC-seq
#
# [5 rows x 54 columns]

# %%
# Get a mapping of experiment accessions to sample ids and vice versa
expacc_to_sample = sra_df.set_index("experiment_accession")["sample_id"].to_dict()
sample_to_expacc = sra_df.set_index("sample_id")["experiment_accession"].to_dict()
expacc_to_sample, sample_to_expacc
# Out:
# ({'SRX14642877': 'SC-Islet_1',
#   'SRX14642878': 'SC-Islet_1',
#   'SRX14642879': 'SC-Islet_2',
#   'SRX14642880': 'SC-Islet_2',
#   'SRX14642885': 'SC-Islet_Stage6_week_2',
#   'SRX14642886': 'SC-Islet_Stage6_week_2',
#   'SRX14642887': 'SC-Islet_Stage6_week_3',
#   'SRX14642888': 'SC-Islet_Stage6_week_3',
#   'SRX14642889': 'SC-Islet_Stage6_week_4',
#   'SRX14642890': 'SC-Islet_Stage6_week_4',
#   'SRX14642891': 'Human_Islet_1',
#   'SRX14642892': 'Human_Islet_1',
#   'SRX14642893': 'Human_Islet_2',
#   'SRX14642894': 'Human_Islet_2',
#   'SRX14642895': 'Transplanted_SC-Islet_1',
#   'SRX14642896': 'Transplanted_SC-Islet_1',
#   'SRX14642897': 'Transplanted_SC-Islet_2',
#   'SRX14642898': 'Transplanted_SC-Islet_2',
#   'SRX14642899': 'Transplanted_SC-Islet_3',
#   'SRX14642900': 'Transplanted_SC-Islet_3',
#   'SRX14642901': 'CRISPRA_SC-Islet_CTCF_Untreated_Control',
#   'SRX14642902': 'CRISPRA_SC-Islet_CTCF_Untreated_Control',
#   'SRX14642903': 'CRISPRA_SC-Islet_CTCF_Doxycycline',
#   'SRX14642904': 'CRISPRA_SC-Islet_CTCF_Doxycycline',
#   'SRX14642905': 'SC-Islet_GFP_Control',
#   'SRX14642906': 'SC-Islet_GFP_Control',
#   'SRX14642907': 'SC-Islet_ARID1B_knockdown',
#   'SRX14642908': 'SC-Islet_ARID1B_knockdown',
#   'SRX17520825': 'SC-Islet_Stage6_month_6',
#   'SRX17520826': 'SC-Islet_Stage6_month_6',
#   'SRX17520827': 'SC-Islet_Stage6_month_12',
#   'SRX17520828': 'SC-Islet_Stage6_month_12',
#   'SRX19667602': 'Human_Islet_3',
#   'SRX19667603': 'Human_Islet_3',
#   'SRX19667604': 'Human_Islet_4',
#   'SRX19667605': 'Human_Islet_4'},
#  {'SC-Islet_1': 'SRX14642878',
#   'SC-Islet_2': 'SRX14642880',
#   'SC-Islet_Stage6_week_2': 'SRX14642886',
#   'SC-Islet_Stage6_week_3': 'SRX14642888',
#   'SC-Islet_Stage6_week_4': 'SRX14642890',
#   'Human_Islet_1': 'SRX14642892',
#   'Human_Islet_2': 'SRX14642894',
#   'Transplanted_SC-Islet_1': 'SRX14642896',
#   'Transplanted_SC-Islet_2': 'SRX14642898',
#   'Transplanted_SC-Islet_3': 'SRX14642900',
#   'CRISPRA_SC-Islet_CTCF_Untreated_Control': 'SRX14642902',
#   'CRISPRA_SC-Islet_CTCF_Doxycycline': 'SRX14642904',
#   'SC-Islet_GFP_Control': 'SRX14642906',
#   'SC-Islet_ARID1B_knockdown': 'SRX14642908',
#   'SC-Islet_Stage6_month_6': 'SRX17520826',
#   'SC-Islet_Stage6_month_12': 'SRX17520828',
#   'Human_Islet_3': 'SRX19667603',
#   'Human_Islet_4': 'SRX19667605'})

# %% [markdown]
# # Rename files for CellRanger-ARC

# %%
# Rename for CellRanger
for dataset in datasets:
    fastq_files = glob.glob(os.path.join(dataset, "*.fastq.gz"))
    file_mapping = {}
    for fastq_file in fastq_files:
        read_type = fastq_file.split("_")[-1].split(".")[0]
        file_path = os.path.dirname(fastq_file)
        exp_acc = os.path.basename(file_path).split("_")[0]
        sample_id = expacc_to_sample[exp_acc]
        new_file = f"{file_path}/{sample_id}_S1_L001_R{read_type}_001.fastq.gz"
        file_mapping[fastq_file] = new_file
        cmd = f"mv {fastq_file} {new_file}"
        print(cmd)
        #os.system(cmd)
    with open(os.path.join(file_path, "file_mapping.pickle"), "wb") as f:
        pickle.dump(file_mapping, f)
# Out:
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642887/SRR18511707_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642887/SC-Islet_Stage6_week_3_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642887/SRR18511707_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642887/SC-Islet_Stage6_week_3_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642887/SRR18511707_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642887/SC-Islet_Stage6_week_3_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642891/SRR18511711_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642891/Human_Islet_1_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642891/SRR18511711_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642891/Human_Islet_1_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642891/SRR18511711_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642891/Human_Islet_1_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642896/SRR18511717_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642896/Transplanted_SC-Islet_1_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642896/SRR18511717_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642896/Transplanted_SC-Islet_1_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642878/SRR18511697_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642878/SC-Islet_1_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642878/SRR18511697_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642878/SC-Islet_1_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520828/SRR21518366_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520828/SC-Islet_Stage6_month_12_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520828/SRR21518366_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520828/SC-Islet_Stage6_month_12_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642890/SRR18511710_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642890/SC-Islet_Stage6_week_4_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642890/SRR18511710_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642890/SC-Islet_Stage6_week_4_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667604/SRR23854916_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667604/Human_Islet_4_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667604/SRR23854916_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667604/Human_Islet_4_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667604/SRR23854916_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667604/Human_Islet_4_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642908/SRR18511729_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642908/SC-Islet_ARID1B_knockdown_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642908/SRR18511729_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642908/SC-Islet_ARID1B_knockdown_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642880/SRR18511699_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642880/SC-Islet_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642880/SRR18511699_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642880/SC-Islet_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642885/SRR18511704_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642885/SC-Islet_Stage6_week_2_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642885/SRR18511704_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642885/SC-Islet_Stage6_week_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642885/SRR18511704_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642885/SC-Islet_Stage6_week_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642904/SRR18511725_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642904/CRISPRA_SC-Islet_CTCF_Doxycycline_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642904/SRR18511725_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642904/CRISPRA_SC-Islet_CTCF_Doxycycline_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642877/SRR18511696_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642877/SC-Islet_1_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642877/SRR18511696_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642877/SC-Islet_1_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642877/SRR18511696_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642877/SC-Islet_1_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642889/SRR18511709_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642889/SC-Islet_Stage6_week_4_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642889/SRR18511709_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642889/SC-Islet_Stage6_week_4_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642889/SRR18511709_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642889/SC-Islet_Stage6_week_4_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642905/SRR18511726_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642905/SC-Islet_GFP_Control_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642905/SRR18511726_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642905/SC-Islet_GFP_Control_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642905/SRR18511726_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642905/SC-Islet_GFP_Control_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642897/SRR18511718_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642897/Transplanted_SC-Islet_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642897/SRR18511718_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642897/Transplanted_SC-Islet_2_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642897/SRR18511718_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642897/Transplanted_SC-Islet_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642888/SRR18511708_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642888/SC-Islet_Stage6_week_3_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642888/SRR18511708_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642888/SC-Islet_Stage6_week_3_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642892/SRR18511712_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642892/Human_Islet_1_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642892/SRR18511712_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642892/Human_Islet_1_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642894/SRR18511715_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642894/Human_Islet_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642894/SRR18511715_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642894/Human_Islet_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642895/SRR18511716_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642895/Transplanted_SC-Islet_1_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642895/SRR18511716_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642895/Transplanted_SC-Islet_1_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642895/SRR18511716_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642895/Transplanted_SC-Islet_1_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520825/SRR21518362_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520825/SC-Islet_Stage6_month_6_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520825/SRR21518362_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520825/SC-Islet_Stage6_month_6_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520825/SRR21518362_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520825/SC-Islet_Stage6_month_6_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642886/SRR18511706_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642886/SC-Islet_Stage6_week_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642886/SRR18511706_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642886/SC-Islet_Stage6_week_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642901/SRR18511722_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642901/CRISPRA_SC-Islet_CTCF_Untreated_Control_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642901/SRR18511722_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642901/CRISPRA_SC-Islet_CTCF_Untreated_Control_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642901/SRR18511722_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642901/CRISPRA_SC-Islet_CTCF_Untreated_Control_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642903/SRR18511724_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642903/CRISPRA_SC-Islet_CTCF_Doxycycline_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642903/SRR18511724_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642903/CRISPRA_SC-Islet_CTCF_Doxycycline_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642903/SRR18511724_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642903/CRISPRA_SC-Islet_CTCF_Doxycycline_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642898/SRR18511719_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642898/Transplanted_SC-Islet_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642898/SRR18511719_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642898/Transplanted_SC-Islet_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642902/SRR18511723_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642902/CRISPRA_SC-Islet_CTCF_Untreated_Control_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642902/SRR18511723_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642902/CRISPRA_SC-Islet_CTCF_Untreated_Control_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667603/SRR23854915_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667603/Human_Islet_3_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667603/SRR23854915_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667603/Human_Islet_3_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642900/SRR18511721_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642900/Transplanted_SC-Islet_3_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642900/SRR18511721_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642900/Transplanted_SC-Islet_3_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520826/SRR21518363_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520826/SC-Islet_Stage6_month_6_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520826/SRR21518363_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520826/SC-Islet_Stage6_month_6_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642906/SRR18511727_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642906/SC-Islet_GFP_Control_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642906/SRR18511727_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642906/SC-Islet_GFP_Control_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642893/SRR18511713_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642893/Human_Islet_2_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642893/SRR18511713_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642893/Human_Islet_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642893/SRR18511713_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642893/Human_Islet_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667602/SRR23854914_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667602/Human_Islet_3_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667602/SRR23854914_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667602/Human_Islet_3_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667602/SRR23854914_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667602/Human_Islet_3_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642899/SRR18511720_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642899/Transplanted_SC-Islet_3_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642899/SRR18511720_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642899/Transplanted_SC-Islet_3_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642899/SRR18511720_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642899/Transplanted_SC-Islet_3_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642879/SRR18511698_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642879/SC-Islet_2_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642879/SRR18511698_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642879/SC-Islet_2_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642879/SRR18511698_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642879/SC-Islet_2_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667605/SRR23854917_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667605/Human_Islet_4_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667605/SRR23854917_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX19667605/Human_Islet_4_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642907/SRR18511728_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642907/SC-Islet_ARID1B_knockdown_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642907/SRR18511728_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642907/SC-Islet_ARID1B_knockdown_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642907/SRR18511728_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX14642907/SC-Islet_ARID1B_knockdown_S1_L001_R2_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520827/SRR21518365_1.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520827/SC-Islet_Stage6_month_12_S1_L001_R1_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520827/SRR21518365_3.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520827/SC-Islet_Stage6_month_12_S1_L001_R3_001.fastq.gz
# mv /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520827/SRR21518365_2.fastq.gz /cellar/users/aklie/data/datasets/Augsornworawat2023_sc-islet_10X-Multiome/fastq/07Nov23/SRP366403/SRX17520827/SC-Islet_Stage6_month_12_S1_L001_R2_001.fastq.gz

# %%
# Check sizes
sra_df[["run_accession", "experiment_accession", "sample_id", "total_spots"]].sort_values("total_spots", ascending=False)
# Out:
#    run_accession experiment_accession  \
# 25   SRR18511727          SRX14642906
# 9    SRR18511710          SRX14642890
# 33   SRR23854915          SRX19667603
# 35   SRR23854917          SRX19667605
# 27   SRR18511729          SRX14642908
# 23   SRR18511725          SRX14642904
# 15   SRR18511717          SRX14642896
# 31   SRR21518366          SRX17520828
# 19   SRR18511721          SRX14642900
# 5    SRR18511705          SRX14642886
# 21   SRR18511723          SRX14642902
# 12   SRR18511713          SRX14642893
# 13   SRR18511714          SRX14642894
# 17   SRR18511719          SRX14642898
# 6    SRR18511707          SRX14642887
# 22   SRR18511724          SRX14642903
# 24   SRR18511726          SRX14642905
# 29   SRR21518363          SRX17520826
# 26   SRR18511728          SRX14642907
# 20   SRR18511722          SRX14642901
# 7    SRR18511708          SRX14642888
# 1    SRR18511697          SRX14642878
# 3    SRR18511699          SRX14642880
# 28   SRR21518362          SRX17520825
# 8    SRR18511709          SRX14642889
# 2    SRR18511698          SRX14642879
# 11   SRR18511712          SRX14642892
# 32   SRR23854914          SRX19667602
# 14   SRR18511716          SRX14642895
# 30   SRR21518364          SRX17520827
# 4    SRR18511704          SRX14642885
# 10   SRR18511711          SRX14642891
# 16   SRR18511718          SRX14642897
# 0    SRR18511696          SRX14642877
# 18   SRR18511720          SRX14642899
# 34   SRR23854916          SRX19667604
#
#                                   sample_id  total_spots
# 25                     SC-Islet_GFP_Control    861681365
# 9                    SC-Islet_Stage6_week_4    686180875
# 33                            Human_Islet_3    686166442
# 35                            Human_Islet_4    610834403
# 27                SC-Islet_ARID1B_knockdown    609071041
# 23        CRISPRA_SC-Islet_CTCF_Doxycycline    553404954
# 15                  Transplanted_SC-Islet_1    542450493
# 31                 SC-Islet_Stage6_month_12    539874973
# 19                  Transplanted_SC-Islet_3    518728711
# 5                    SC-Islet_Stage6_week_2    514096708
# 21  CRISPRA_SC-Islet_CTCF_Untreated_Control    504448786
# 12                            Human_Islet_2    480652480
# 13                            Human_Islet_2    479845245
# 17                  Transplanted_SC-Islet_2    469015244
# 6                    SC-Islet_Stage6_week_3    458763865
# 22        CRISPRA_SC-Islet_CTCF_Doxycycline    458348010
# 24                     SC-Islet_GFP_Control    444787938
# 29                  SC-Islet_Stage6_month_6    441551364
# 26                SC-Islet_ARID1B_knockdown    434913264
# 20  CRISPRA_SC-Islet_CTCF_Untreated_Control    426488958
# 7                    SC-Islet_Stage6_week_3    421230005
# 1                                SC-Islet_1    419226590
# 3                                SC-Islet_2    417632874
# 28                  SC-Islet_Stage6_month_6    416198619
# 8                    SC-Islet_Stage6_week_4    407902691
# 2                                SC-Islet_2    406975127
# 11                            Human_Islet_1    405302329
# 32                            Human_Islet_3    397389371
# 14                  Transplanted_SC-Islet_1    396007712
# 30                 SC-Islet_Stage6_month_12    369758188
# 4                    SC-Islet_Stage6_week_2    360328095
# 10                            Human_Islet_1    327396237
# 16                  Transplanted_SC-Islet_2    320694424
# 0                                SC-Islet_1    304179888
# 18                  Transplanted_SC-Islet_3    282925620
# 34                            Human_Islet_4    257061146

# %% [markdown]
# # Create CellRanger ARC compatible CSVs
# Construct a 3-column libraries CSV file that specifies the location of the ATAC and GEX FASTQ files associated with the sample. An example
# ```
# fastqs,sample,library_type
# /home/jdoe/runs/HNGEXSQXXX/outs/fastq_path,example,Gene Expression
# /home/jdoe/runs/HNATACSQXX/outs/fastq_path,example,Chromatin Accessibility
# ```
# Note that I had one issue where it looks like the `library_type` in the SRA metadata is incorrect for `SC-Islet_Stage6_month_6 (SRX17520826)` and `SC-Islet_Stage6_month_12 (SRX17520828)` and I had to manually change it from "Chromatin Accessibility" to "Gene Expression" in the CSV file.

# %%
unique_ids = sra_df["sample_id"].unique()
len(unique_ids), unique_ids
# Out:
# (18,
#  array(['SC-Islet_1', 'SC-Islet_2', 'SC-Islet_Stage6_week_2',
#         'SC-Islet_Stage6_week_3', 'SC-Islet_Stage6_week_4',
#         'Human_Islet_1', 'Human_Islet_2', 'Transplanted_SC-Islet_1',
#         'Transplanted_SC-Islet_2', 'Transplanted_SC-Islet_3',
#         'CRISPRA_SC-Islet_CTCF_Untreated_Control',
#         'CRISPRA_SC-Islet_CTCF_Doxycycline', 'SC-Islet_GFP_Control',
#         'SC-Islet_ARID1B_knockdown', 'SC-Islet_Stage6_month_6',
#         'SC-Islet_Stage6_month_12', 'Human_Islet_3', 'Human_Islet_4'],
#        dtype=object))

# %%
library_type_map = {"RNA-Seq": "Gene Expression", "ATAC-seq": "Chromatin Accessibility"}
if not os.path.exists(metadata_dir):
    os.makedirs(metadata_dir)
for sample_id in unique_ids:
    sample_df = sra_df[sra_df["sample_id"] == sample_id]
    sample_df["fastqs"] = sample_df["experiment_accession"].apply(lambda x: os.path.join(fastq_dir, x))
    sample_df["sample"] = sample_df["sample_id"]
    sample_df["library_type"] = sample_df["multiome_part"].apply(lambda x: library_type_map[x])
    sample_df = sample_df[["fastqs", "sample", "library_type"]]

    # if sample_id = SC-Islet_Stage6_month_6 or SC-Islet_Stage6_month_6, tge second row has the wrong library type
    # it should be Gene Expression, not Chromatin Accessibility
    if sample_id in ["SC-Islet_Stage6_month_6", "SC-Islet_Stage6_month_6"]:
        sample_df.iloc[1, 2] = "Gene Expression"
    #sample_df.to_csv(os.path.join(metadata_dir, f"{sample_id}.csv"), index=False)
# Out:
# /cellar/users/aklie/opt/miniconda3/envs/get_data/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /cellar/users/aklie/opt/miniconda3/envs/get_data/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /cellar/users/aklie/opt/miniconda3/envs/get_data/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sample_df
# Out:
#                                                fastqs         sample  \
# 34  /cellar/users/aklie/data/datasets/Augsornworaw...  Human_Islet_4
# 35  /cellar/users/aklie/data/datasets/Augsornworaw...  Human_Islet_4
#
#                library_type
# 34  Chromatin Accessibility
# 35          Gene Expression

# %% [markdown]
# # Check seqkit statistics
# I often spot check these to see if they match up with SRA metadata. A few of these didn't, but going and checking the deposited files confirms that seqkit has the correct number (i.e. the fastqs are probably ok)

# %%
seqkit_df = pd.read_csv(seqkit_stats, sep="\t")
seqkit_df.head()
# Out:
#                                                 file format type   num_seqs  \
# 0  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  304179888
# 1  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  304179888
# 2  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  304179888
# 3  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  419226590
# 4  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  419226590
#
#        sum_len  min_len  avg_len  max_len
# 0  15513174288       51     51.0       51
# 1   4866878208       16     16.0       16
# 2  15513174288       51     51.0       51
# 3  11738344520       28     28.0       28
# 4  62883988500      150    150.0      150

# %%
seqkit_df[~seqkit_df["num_seqs"].isin(sra_df["total_spots"])]
# Out:
#                                                  file format type   num_seqs  \
# 13  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  241665675
# 14  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  241665675
# 33  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  241419128
# 34  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  241419128
# 75  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  142335331
# 76  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  142335331
# 77  /cellar/users/aklie/data/datasets/Augsornworaw...  FASTQ  DNA  142335331
#
#         sum_len  min_len  avg_len  max_len
# 13   6766638900       28     28.0       28
# 14  36249851250      150    150.0      150
# 33   6759735584       28     28.0       28
# 34  36212869200      150    150.0      150
# 75   7116766550       50     50.0       50
# 76   2277365296       16     16.0       16
# 77   7116766550       50     50.0       50

# %%
expacc_to_sample["SRX14642886"]
# Out:
# 'SC-Islet_Stage6_week_2'

# %% [markdown]
# # DONE!

# %% [markdown]
# ---

# %%
exp_accs = [file.split("/")[-1] for file in glob.glob(os.path.join(fastq_dir, "*"))]
sample_ids = [expacc_to_sample[exp_acc] for exp_acc in exp_accs]
exp_accs[:5], sample_ids[:5]
# Out:
# (['SRX14642887', 'SRX14642891', 'SRX14642896', 'SRX14642878', 'SRX17520828'],
#  ['SC-Islet_Stage6_week_3',
#   'Human_Islet_1',
#   'Transplanted_SC-Islet_1',
#   'SC-Islet_1',
#   'SC-Islet_Stage6_month_12'])

# %%
exp_accs
# Out:
# ['SRX14642887',
#  'SRX14642891',
#  'SRX14642896',
#  'SRX14642878',
#  'SRX17520828',
#  'SRX14642890',
#  'SRX19667604',
#  'SRX14642908',
#  'SRX14642880',
#  'SRX14642885',
#  'SRX14642904',
#  'SRX14642877',
#  'SRX14642889',
#  'SRX14642905',
#  'SRX14642897',
#  'SRX14642888',
#  'SRX14642892',
#  'SRX14642894',
#  'SRX14642895',
#  'SRX17520825',
#  'SRX14642886',
#  'SRX14642901',
#  'SRX14642903',
#  'SRX14642898',
#  'SRX14642902',
#  'SRX19667603',
#  'SRX14642900',
#  'SRX17520826',
#  'SRX14642906',
#  'SRX14642893',
#  'SRX19667602',
#  'SRX14642899',
#  'SRX14642879',
#  'SRX19667605',
#  'SRX14642907',
#  'SRX17520827']

# %%
# Grab unique sample ids
unique_ids = list(set(sample_ids))
sorted(unique_ids)
# Out:
# ['CRISPRA_SC-Islet_CTCF_Doxycycline',
#  'CRISPRA_SC-Islet_CTCF_Untreated_Control',
#  'Human_Islet_1',
#  'Human_Islet_2',
#  'Human_Islet_3',
#  'Human_Islet_4',
#  'SC-Islet_1',
#  'SC-Islet_2',
#  'SC-Islet_ARID1B_knockdown',
#  'SC-Islet_GFP_Control',
#  'SC-Islet_Stage6_month_12',
#  'SC-Islet_Stage6_month_6',
#  'SC-Islet_Stage6_week_2',
#  'SC-Islet_Stage6_week_3',
#  'SC-Islet_Stage6_week_4',
#  'Transplanted_SC-Islet_1',
#  'Transplanted_SC-Islet_2',
#  'Transplanted_SC-Islet_3']
